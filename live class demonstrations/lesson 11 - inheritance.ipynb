# %%
class Person:
    def __my_internal_function(self):
        pass
    
    def other_function(self):
        pass

class Employee(Person):
    pass

class Temp(Employee):
    pass

class Manager(Employee):
    pass

# %%
manager = Manager()
temp = Temp()

# %%
isinstance(manager, Person)
# Out:
# True

# %%
isinstance(manager, Manager)
# Out:
# True

# %%
isinstance(manager, Temp)
# Out:
# False

# %%
issubclass(Temp, Employee)
# Out:
# True

# %%
issubclass(Temp, Person)
# Out:
# True

# %%
issubclass(Temp, list)
# Out:
# False

# %%
issubclass(Temp, Manager)
# Out:
# False

# %%
class DifferentList:
    def append(self, other):
        print('no thank you')

# %%
class TodoList:
    stuff = []
    def append(self, other):
        self.stuff.append(other)

# %%
x = [DifferentList(), TodoList(), []]

# %%
for item in x:
    item.append(7)
# Out:
# no thank you

# %%
x
# Out:
# [<__main__.DifferentList at 0x274939bd898>,
#  <__main__.TodoList at 0x274939bd9b0>,
#  [7]]

# %%
x[1].stuff
# Out:
# [7]

# %%
DifferentList.extend = list.extend

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-6c87ddf347a3> in <module>
# ----> 1 list.__locals__
#
# AttributeError: type object 'list' has no attribute '__locals__'

# %%
dir(Person)
# Out:
# ['_Person__my_internal_function',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'other_function']

# %%
x = Person()

# %%
x._Person__my_internal_function()

# %%
x.blah = []

# %%
x.meow = print

# %%
x.meow
# Out:
# <function print>

# %%
x.blah
# Out:
# []

# %%
x.append = list.append

# %%
hasattr
# Out:
# <function hasattr(obj, name, /)>

# %%
hasattr(Person, 'meow')
# Out:
# False

# %%
hasattr(x, 'meow')
# Out:
# True

# %%
hasattr(list, 'append')
# Out:
# True

# %%
hasattr(list, 'items')
# Out:
# False

# %%
hasattr({1:"one"}, 'items')
# Out:
# True
