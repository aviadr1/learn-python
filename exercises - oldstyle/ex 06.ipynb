# %%
abstract = """

1) create and test a regex to:
   match positive integer numbers

    good_matches = [
        "1",
        "12",
        "65324",
        "0",
    ]

    bad_matches = [
        "blah",
        "4-5",
        "4.0"
        "-10"
    ]
   
2) create and test a regex to:
   match positive or negative integers
   
  good_matches = [
       "1",
       "12",
       "65324",
       "+19",
       "-10",
       "0"
   ]
   
   bad_matches = [
       "-0",
       "+0",
       "blah",
       "f123",
       "123you",
       "4-5",
       "4.0"
   ]   

3) create and test a regex to:
   match decimal numbers
   
   
  good_matches = [
       "1",
       "12",
       "123.4554",
       "0.43",
       "-10",
       "0",
       "+2.3",
       "-2.3"
   ]
   
   bad_matches = [
       "-0",
       "+0",
       "blah",
       "f123",
       "123you",
       "4-5",
       "..34",
       ".34",
       "0.",
       "234."
   ]      

4) create and test a regex to:
   words that look like verbs and end in '-ing'

  good_matches = [
       "jumping",
       "eating",
       'sleeping',
       'ting',
       'bing',
       'zipziplinging'
   ]
   
   bad_matches = [
       'jump',
       'ing',
       'jump ing',
       '_ing',
       '234ing'
   ]
   
5) create and test a regex to:
   lines that start with the word 'cats' and end with the words 'are awesome' 
   
    good_matches = [
       "cats are awesome",
       "cats that sleep are awesome",
       'cats that can count to 10 are awesome',
       'cats 1234567890-/.,gdf/.g, are awesome',
   ]
   
   bad_matches = [
       'cat'
       'awesome',
       'cats are',
       'cats are awesome too',
       'my cats are awesome',
   ]
   
*** TODO: excersizes for iterall and match groups
   
"""

# %%
import re

good_matches = [
   "1",
   "12",
   "65324",
   "0",
]

bad_matches = [
    "blah",
    "f123",
    "245fsd"
    "4-5",
    "4.0"
    "-10"
]

regex = r"\b[0-9]+\b"
for test in good_matches:
    if not re.fullmatch(regex, test):
        print("failed:", test)

for test in bad_matches:
    if re.fullmatch(regex, test):
        print("failed:", test)

print(regex)
# Out:
# \b[0-9]+\b

# %%
good_matches = [
   "1",
   "12",
   "65324",
   "+19",
   "-10",
   "0"
]

bad_matches = [
   "-0",
   "+0",
   "blah",
   "f123",
   "123you",
   "4-5",
   "4.0"
]

regex = r"([+\-]?[1-9][0-9]*)|0"
for test in good_matches:
    if not re.fullmatch(regex, test):
        print("failed:", test)

for test in bad_matches:
    if re.fullmatch(regex, test):
        print("failed:", test)

print(regex)
# Out:
# ([+\-]?[1-9][0-9]*)|0

# %%
"""
3*) create and test a regex to:
   match decimal numbers
   
   
  good_matches = [
       "1",
       "12",
       "123.4554",
       "0.43",
       "-10",
       "0",
       "+2.3",
       "-2.3"
   ]
   
   bad_matches = [
       "-0",
       "+0",
       "blah",
       "f123",
       "123you",
       "4-5",
       "..34",
       ".34",
       "0.",
       "234."
   ]
"""

good_matches = [
   "1",
   "12",
   "123.4554",
   "0.43",
   "-10",
   "0",
   "+2.3",
   "-2.3"
]

bad_matches = [
   "-0",
   "+0",
   "blah",
   "f123",
   "123you",
   "4-5",
   "..34",
   ".34",
   "0.",
   "234."
]

regex = r"([+-]?[0-9]+\.[0-9]+)|([+\-]?[1-9][0-9]*)|0"

for test in good_matches:
    if not re.fullmatch(regex, test):
        print("failed:", test)

for test in bad_matches:
    if re.fullmatch(regex, test):
        print("failed:", test)

print(regex)
# Out:
# ([+-]?[0-9]+\.[0-9]+)|([+\-]?[1-9][0-9]*)|0

# %%
"""
4) create and test a regex to:
   words that look like verbs and end in '-ing'

  good_matches = [
       "jumping",
       "eating",
       'sleeping',
       'ting',
       'bing',
       'zipziplinging'
   ]
   
   bad_matches = [
       'jump',
       'ing',
       'jump ing',
       '_ing',
       '234ing'
   ]      
   
"""

good_matches = [
   "jumping",
   "eating",
   'sleeping',
   'ting',
   'bing',
   'zipziplinging'
]

bad_matches = [
   'jump',
   'ing',
   'jump ing',
   '_ing',
   '234ing'
]

regex = r"[a-zA-Z]+ing"

for test in good_matches:
    if not re.fullmatch(regex, test):
        print("failed:", test)

for test in bad_matches:
    if re.fullmatch(regex, test):
        print("failed:", test)

print(regex)
# Out:
# [a-zA-Z]+ing

# %%
"""
5) create and test a regex to:
   lines that start with the word 'cats' and end with the words 'are awesome' 
   
    good_matches = [
       "cats are awesome",
       "cats that sleep are awesome",
       'cats that can count to 10 are awesome',
       'cats 1234567890-/.,gdf/.g, are awesome',
   ]
   
   bad_matches = [
       'cat'
       'awesome',
       'cats are',
       'cats are awesome too',
       'my cats are awesome'
   ]   
   
"""

good_matches = [
   "cats are awesome",
   "cats that sleep are awesome",
   'cats that can count to 10 are awesome',
   'cats 1234567890-/.,gdf/.g, are awesome',
]

bad_matches = [
   'cat'
   'awesome',
   'cats are',
   'cats are awesome too',
   'my cats are awesome',
]

regex = r'cats.*are awesome'

for test in good_matches:
    if not re.fullmatch(regex, test):
        print("failed:", test)

for test in bad_matches:
    if re.fullmatch(regex, test):
        print("failed:", test)

print(regex)
# Out:
# cats.*are awesome
